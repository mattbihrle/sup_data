# %%
# # Install scipy
#     # Ensure we have system access
# import sys
# !{sys.executable} -m pip --version

# # Install w/o virtual environment

# !{sys.executable} -m pip install scipy
# import os
# # os.getcwd()
# import sys
# !{sys.executable} -m pip install pandas

# %%
# Import packages 
import scipy
import re
import pandas as pd
import datetime

# %%
# import data
import scipy.io
temp = scipy.io.loadmat('..\\data\\metadata\\LSEO24h_temp.mat')

key_names = list(temp.keys())
key_names

# Extract data columns
data_cols = [col for col in key_names if not re.match("\\A_.", col)]
print("data_cols = ", data_cols)

# # Turn into df
# Out:
# data_cols =  ['SN', 'T', 'dep', 't']

# %%
# Testing
data = pd.DataFrame.from_dict(temp['T'], orient = 'columns')
time = list(datetime.datetime.fromtimestamp(temp['t'][0])
print(data)
view(data)
# Out:
# ---------------------------------------------------------------------------
#
# TypeError                                 Traceback (most recent call last)
#
# Cell In[32], line 3
#
#       1 # Testing
#
#       2 data = pd.DataFrame.from_dict(temp['T'], orient = 'columns')
#
# ----> 3 time = list(datetime.datetime.fromtimestamp(temp['t'][0], datetime.timezone.utc)
#
#       4 )
#
#       5 print(data)
#
#       6 view(data)
#
#
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
print(temp['t'][0])
# Out:
# [739443.25       739443.29166667 739443.33333333 ... 739834.375
#  739834.41666667 739834.45833333]

# %%
import time
time.sleep(3)

# %%
def say_hello(recipient):
    return 'Hello, {}!'.format(recipient)
say_hello('Tim')
# Out:
# 'Hello, Tim!'

# %%
import numpy as np

def square(x):
    return x * x

# %%
x = np.random.randint(1, 10)
y = square(x)
print('%d squared is %d' % (x, y))
# Out:
# 2 squared is 4
